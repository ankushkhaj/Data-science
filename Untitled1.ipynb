# %%
with open('C:/Personal/09142640/Desktop/poem.txt') as poem_file:
    text = poem_file.readlines()
    print("This file is {} lines long".format(len(text)))
    for line in text:
        print(line)
# Out:
# This file is 19 lines long
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than *right* now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!

# %%
import pandas as pd
df=pd.read_csv("C:/Personal/09142640/Desktop/NBA_player_of_the_week.csv")
print(df)
# Out:
#       Age Conference       Date  Draft Year  Height                  Player  \
# 0      29        NaN  14-Apr-85        1978   5-Jun  Micheal Ray Richardson
# 1      23        NaN   7-Apr-85        1982   6-Jun             Derek Smith
# 2      28        NaN   1-Apr-85        1979   6-Jun             Calvin Natt
# 3      37        NaN  24-Mar-85        1969   2-Jul     Kareem Abdul-Jabbar
# 4      28        NaN  17-Mar-85        1978   9-Jun              Larry Bird
# 5      26        NaN  10-Mar-85        1980   4-Jun        Darrell Griffith
# 6      24        NaN   3-Mar-85        1982   3-Jun            Sleepy Floyd
# 7      25        NaN  24-Feb-85        1981   6-Jun            Mark Aguirre
# 8      25        NaN  17-Feb-85        1979   9-Jun           Magic Johnson
# 9      25        NaN   3-Feb-85        1982   7-Jun       Dominique Wilkins
# 10     32        NaN  27-Jan-85        1974  11-Jun            Tom McMillen
# 11     22        NaN  20-Jan-85        1984   6-Jun          Michael Jordan
# 12     31        NaN  13-Jan-85        1975   2-Jun           World B. Free
# 13     23        NaN   6-Jan-85        1981   1-Jun            Isiah Thomas
# 14     29        NaN  30-Dec-84        1978   5-Jun  Micheal Ray Richardson
# 15     23        NaN  23-Dec-84        1982   9-Jun          Terry Cummings
# 16     23        NaN  16-Dec-84        1982   6-Jun             Derek Smith
# 17     25        NaN   9-Dec-84        1981   9-Jun       Orlando Woolridge
# 18     29        NaN   2-Dec-84        1977  11-Jun              Jack Sikma
# 19     28        NaN  25-Nov-84        1977   7-Jun            Bernard King
# 20     29        NaN  18-Nov-84        1976  10-Jun            Moses Malone
# 21     31        NaN  11-Nov-84        1976   7-Jun            Alex English
# 22     26        NaN   4-Nov-84        1981  10-Jun             Larry Nance
# 23     26        NaN  13-Apr-86        1982   7-Jun       Dominique Wilkins
# 24     28        NaN   6-Apr-86        1981  10-Jun           Herb Williams
# 25     23        NaN  30-Mar-86        1984   6-Jun         Charles Barkley
# 26     30        NaN  23-Mar-86        1976   5-Jun          Adrian Dantley
# 27     29        NaN  16-Mar-86        1978   9-Jun              Larry Bird
# 28     26        NaN   9-Mar-86        1979   9-Jun           Magic Johnson
# 29     23        NaN   2-Mar-86        1984   6-Jun         Charles Barkley
# ...   ...        ...        ...         ...     ...                     ...
# 1115   26       East  29-Jan-18        2012   203cm         Khris Middleton
rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.figure(figsize=(1,1))
df=pd.read_csv("C:/Personal/09142640/Desktop/NBA_player_of_the_week1.csv")
df1=df[df.Season_short==1985]
fig,ax=plt.subplots()
#All players with their playing years
ax.plot(df1['Player'],df1['Season_short'],linestyle='', marker='o')
plt.ylabel('Year')
#plt.title('Player stats')#plt.subplot(1, 2, 2)
#plt.plot(df1['Season short'], color='green')
plt.xlabel('Player')
#plt.xticks(y_pos, bars)
plt.title('Player stats')
plt.show()

#Top 5 players in subplot
plt.subplot(1, 2, 2)
#counts=df.groupby('Player')['Player'].count()
counts=df['Player'].value_counts()
#counts
df_count = pd.DataFrame(counts)
#count=df_count[columns='count']

df_counts=counts.reset_index()
df_counts
Top_5=df_counts.sort_values('Player',ascending=False).head(5)
#top 5 players  
plt.plot(Top_5['Player'],Top_5['index'])
plt.title('Top 5 NBA Players based on Awards')
plt.xlabel('Awards Won')
plt.ylabel('Player')
plt.show()
bar_width = 0.35
opacity = 0.8

#Top 5 players on barchart
bar1= plt.bar( Top_5['index'],Top_5['Player'], bar_width,
                 alpha=opacity,
                 color='b'
                 )
plt.xlabel('Player')
plt.ylabel('Awards')
#plt.legend()
plt.title('Top 5 NBA Players based on Awards')
plt.tight_layout()
plt.show()

#top5 players with their playing years
fig,ax=plt.subplots()
#ax.plot(df1['Player'],df1['Season_short']<=Top_5['index'],linestyle='', marker='o')
df3= df.loc[df['Player'] .isin(Top_5['index'])]
plt.plot(df3['Player'],df3['Season_short'],linestyle=' ', marker='o')
plt.title('Top 5 NBA Players with their playing years')
plt.ylabel('Year')
plt.xlabel('Player')
plt.show()

# %%
# Make the random function consistent and replicable.
np.random.seed(1221)

# Make a blank data frame.
df = pd.DataFrame()

# Add a column of random numbers between 0 and 1.
df['rand'] = np.random.rand(100)
df['rand_sq'] = df['rand'] ** 2
df['rand_shift'] = df['rand'] + 2

# When creating a data frame an index column of counts is created, counting from 0.
# Here we do a few transforms on that index to create some extra columns.
df['counts_sq'] = df.index ** 2 
df['counts_sqrt'] = np.sqrt(df.index)
df
#plt.plot(df['rand'])
#plt.show()
# Out:
#         rand   rand_sq  rand_shift  counts_sq  counts_sqrt
# 0   0.469448  0.220382    2.469448          0     0.000000
# 1   0.801031  0.641651    2.801031          1     1.000000
# 2   0.199776  0.039911    2.199776          4     1.414214
# 3   0.982491  0.965289    2.982491          9     1.732051
# 4   0.072386  0.005240    2.072386         16     2.000000
# 5   0.508843  0.258921    2.508843         25     2.236068
# 6   0.538598  0.290088    2.538598         36     2.449490
# 7   0.525917  0.276589    2.525917         49     2.645751
# 8   0.100314  0.010063    2.100314         64     2.828427
# 9   0.138076  0.019065    2.138076         81     3.000000
# 10  0.225879  0.051021    2.225879        100     3.162278
# 11  0.033813  0.001143    2.033813        121     3.316625
# 12  0.053727  0.002887    2.053727        144     3.464102
# 13  0.774183  0.599359    2.774183        169     3.605551
# 14  0.063352  0.004013    2.063352        196     3.741657
# 15  0.081261  0.006603    2.081261        225     3.872983
# 16  0.779384  0.607439    2.779384        256     4.000000
# 17  0.340827  0.116163    2.340827        289     4.123106
# 18  0.629402  0.396146    2.629402        324     4.242641
# 19  0.323670  0.104762    2.323670        361     4.358899
# 20  0.002293  0.000005    2.002293        400     4.472136
# 21  0.068923  0.004750    2.068923        441     4.582576
# 22  0.288379  0.083162    2.288379        484     4.690416
# 23  0.069388  0.004815    2.069388        529     4.795832
# 24  0.558787  0.312243    2.558787        576     4.898979
# 25  0.394927  0.155967    2.394927        625     5.000000
# 26  0.970006  0.940912    2.970006        676     5.099020
# 27  0.588277  0.346069    2.588277        729     5.196152
# 28  0.178530  0.031873    2.178530        784     5.291503
# 29  0.852657  0.727025    2.852657        841     5.385165
# ..       ...       ...         ...        ...          ...
# 70  0.821033  0.674096    2.821033       4900     8.366600
# 71  0.100752  0.010151    2.100752       5041     8.426150
# 72  0.454609  0.206669    2.454609       5184     8.485281
# 73  0.220531  0.048634    2.220531       5329     8.544004
# 74  0.570858  0.325878    2.570858       5476     8.602325
# 75  0.219670  0.048255    2.219670       5625     8.660254
# 76  0.809325  0.655006    2.809325       5776     8.717798
# 77  0.723617  0.523622    2.723617       5929     8.774964
# 78  0.727880  0.529810    2.727880       6084     8.831761
# 79  0.445201  0.198204    2.445201       6241     8.888194
# 80  0.716168  0.512897    2.716168       6400     8.944272
# 81  0.999118  0.998236    2.999118       6561     9.000000
# 82  0.661557  0.437657    2.661557       6724     9.055385
# 83  0.517362  0.267664    2.517362       6889     9.110434
# 84  0.868825  0.754857    2.868825       7056     9.165151
# 85  0.976762  0.954063    2.976762       7225     9.219544
# 86  0.745961  0.556459    2.745961       7396     9.273618
# 87  0.571029  0.326074    2.571029       7569     9.327379
# 88  0.596220  0.355479    2.596220       7744     9.380832
# 89  0.513032  0.263202    2.513032       7921     9.433981
# 90  0.643205  0.413713    2.643205       8100     9.486833
# 91  0.684461  0.468487    2.684461       8281     9.539392
# 92  0.502429  0.252435    2.502429       8464     9.591663
# 93  0.035911  0.001290    2.035911       8649     9.643651
# 94  0.355176  0.126150    2.355176       8836     9.695360
# 95  0.138284  0.019122    2.138284       9025     9.746794
# 96  0.593936  0.352760    2.593936       9216     9.797959
# 97  0.716772  0.513762    2.716772       9409     9.848858
# 98  0.029904  0.000894    2.029904       9604     9.899495
# 99  0.207413  0.043020    2.207413       9801     9.949874
#
# [100 rows x 5 columns]

# %%
import pandas as pd

# Make a blank data frame.
df = pd.DataFrame()

# Populate it with data.
df['age'] = [28, 42, 27, 24, 35, 54, 35, 37]
df
# Out:
#    age
# 0   28
# 1   42
# 2   27
# 3   24
# 4   35
# 5   54
# 6   35
# 7   37

# %%
(values, counts) = np.unique(df['age'], return_counts=True)
(values, counts)
# Out:
# (array([24, 27, 28, 35, 37, 42, 54], dtype=int64),
#  array([1, 1, 1, 2, 1, 1, 1], dtype=int64))

# %%
ind = np.argmax(counts)
ind
# Out:
# 3

# %%
values[ind]
# Out:
# 35

# %%
pop=pd.DataFrame()
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)
pop
pop.hist(layout=(2, 1), sharex=True)
plt.show()
print(pop.max())
print(pop.min())
# Out:
# low_var     100.862227
# high_var    421.076788
# dtype: float64
# low_var      22.885888
# high_var   -285.875122
# dtype: float64
